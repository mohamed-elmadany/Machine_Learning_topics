# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler

# %%
data=[[0,61],[0,62],[1,63],[1,64]]

# %%
scaler=StandardScaler()
normaliz=MinMaxScaler()
Robust=RobustScaler()

# %%
scaler.fit_transform(data)
# Out:
# array([[-1.        , -1.34164079],
#        [-1.        , -0.4472136 ],
#        [ 1.        ,  0.4472136 ],
#        [ 1.        ,  1.34164079]])

# %%
normaliz.fit_transform(data)
# Out:
# array([[0.        , 0.        ],
#        [0.        , 0.33333333],
#        [1.        , 0.66666667],
#        [1.        , 1.        ]])

# %%
Robust.fit_transform(data)
# Out:
# array([[-0.5       , -1.        ],
#        [-0.5       , -0.33333333],
#        [ 0.5       ,  0.33333333],
#        [ 0.5       ,  1.        ]])
